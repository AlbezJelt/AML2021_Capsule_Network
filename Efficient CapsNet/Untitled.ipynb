# %%
import tensorflow_datasets as tfds
import os
from tqdm import tqdm
import matplotlib.pyplot as plt
import numpy as np
from utils import pre_process_patch_camelyon as pppc

# %%
(ds_train, ds_valid), ds_info = tfds.load(
                'patch_camelyon',
                data_dir=os.path.join(os.getcwd(), 'tensorflow_datasets'),
                download=False,
                split=['train', 'validation'],
                shuffle_files=True,
                as_supervised=False,
                with_info=True)

# %%
print(ds_info.features['label'].names)
# Out:
# ['0', '1']

# %%
for batch in ds_train.take(10):
    print(batch['id'].numpy())
    plt.imshow(np.squeeze(batch['image'].numpy()))
    plt.show()
    print(batch['label'].numpy())
    print('')
# Out:
# b'train_171848'
# 0
#
# b'train_186001'
# 0
#
# b'train_50113'
# 0
#
# b'train_85408'
# 0
#
# b'train_195490'
# 0
#
# b'train_158648'
# 0
#
# b'train_178382'
# 1
#
# b'train_178042'
# 1
#
# b'train_42278'
# 0
#
# b'train_167303'
# 0

# %%
# x_train, t_train = pppc.pre_process(ds_train)

# %%
ds_train.
