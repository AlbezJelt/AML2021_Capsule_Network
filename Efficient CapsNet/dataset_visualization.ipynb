# %%
import tensorflow as tf
import matplotlib.pyplot as plt
import numpy as np
from utils import Dataset

# %% [markdown]
# # Load the dataset

# %%
data = Dataset('PATCH_CAMELYON')
# Out:
# [INFO] Dataset loaded!

# %% [markdown]
# # Visualize some raw images from the train set

# %%
for sample in data.tf_train.take(6):
    img = sample['image'].numpy()
    id = sample['id'].numpy().decode('utf-8').replace('train_', '')
    label = sample['label'].numpy()
    print(f"id: {id}", f"label: {label}")
    plt.imshow(img)
    plt.show()
    # plt.imsave(f"{id}_{label}.png", img)
# Out:
# id: 260342 label: 1
# id: 259707 label: 1
# id: 41912 label: 1
# id: 254750 label: 0
# id: 25168 label: 0
# id: 146724 label: 0
