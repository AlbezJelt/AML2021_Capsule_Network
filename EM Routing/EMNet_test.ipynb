# %%
from src import EMNet
from src.utils.config import LOCAL_STORAGE as cwd
import pathlib
import os
# Out:
# WARNING:tensorflow:Deprecation warnings have been disabled. Set TF_ENABLE_DEPRECATION_WARNINGS=1 to re-enable them.

# %%
load_dir = os.path.join(
  cwd, 'logs', 'PatchCamelyon', '20210903_'
  )

# %%
emnet = EMNet('PatchCamelyon', load_dir = load_dir)
# Out:
# 2021-09-12 17:05:41 INFO: Parameters saved to file: /workspaces/Capsule-Network-Tests/EM Routing/logs/PatchCamelyon/20210912_/train/params/params.json
# 2021-09-12 17:05:41 INFO: Using dataset: PatchCamelyon

# %%
emnet.test()
# Out:
# 2021-09-12 17:05:41 INFO: name: 20210903_
# 2021-09-12 17:05:41 INFO: parent_dir: /workspaces/Capsule-Network-Tests/EM Routing/logs/PatchCamelyon
# 2021-09-12 17:05:41 INFO: test_dir: /workspaces/Capsule-Network-Tests/EM Routing/logs/PatchCamelyon/20210903_/test
# 2021-09-12 17:05:41 INFO: Loaded parameters from file: /workspaces/Capsule-Network-Tests/EM Routing/logs/PatchCamelyon/20210903_/train/params/params.json
# 2021-09-12 17:05:41 INFO: Using dataset: PatchCamelyon
# 2021-09-12 17:05:41 INFO: BUILD TEST GRAPH
# WARNING:tensorflow:From /workspaces/Capsule-Network-Tests/EM Routing/src/EMNet.py:559: The name tf.train.get_or_create_global_step is deprecated. Please use tf.compat.v1.train.get_or_create_global_step instead.
# 2021-09-12 17:05:41 WARNING: From /workspaces/Capsule-Network-Tests/EM Routing/src/EMNet.py:559: The name tf.train.get_or_create_global_step is deprecated. Please use tf.compat.v1.train.get_or_create_global_step instead.
# ...
